# %%
id_1 = "#4"
average_grade_1 = "A"
test_score_1 = 90

id_2 = "#5"
average_grade_2 = "A"
test_score_2 = 70

no_duplicates = id_1 != id_2
print("No duplicates.")
print(no_duplicates)
# Out:
# No duplicates.
# True

# %%
print("Same average grade. ")
print(same_average)
\n
# Out:
#   File "<ipython-input-2-cdcda8363099>", line 3
#     \n
#        ^
# SyntaxError: unexpected character after line continuation character

# %%
print("Same average grade. ")
print(same_average)
# Out:
# Same average grade.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Desktop/pythonProjects/Comparing_Dataset_Entries.py in <module>
#       1 print("Same average grade. ")
# ----> 2 print(same_average)
#
# NameError: name 'same_average' is not defined

# %%
print("Same average grade.")
print(same_average)
# Out:
# Same average grade.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Desktop/pythonProjects/Comparing_Dataset_Entries.py in <module>
#       1 print("Same average grade.")
# ----> 2 print(same_average)
#
# NameError: name 'same_average' is not defined

# %%
same_average = average_grade_1 == average_grade_2
print("Same average grade.")
print(same_average)
# Out:
# Same average grade.
# True
